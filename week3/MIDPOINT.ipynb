# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler-Fronczke-CIS-115/blob/main/week3/MIDPOINT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#assign valuables to variables: Name, birth_year, current_year, goal
name = "Jordan"
goal = "Learn python"
birth_year = 2004
current_year = 2026

#calculate age
age = current_year - birth_year

#print top border
print("=" * 25)

#print bios
print("name:", name, ", age:", str(age), ", Goal:", goal)

#print bottom boarder
print("=" * 25)
