# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler-Fronczke-CIS-115/blob/main/week14/week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# N/A

# CLASS DEFINITIONS
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.is_available = True

# __str__ method will be added in 'COMPLETION'
    def __str__(self):
        pass

# checkout method will be added in 'COMPLETION'
    def checkout(self):
        pass

# return_book method will be added in 'COMPLETION'
    def return_book(self):
        pass

# PROGRAM LOGIC
# Create one book object to test __init__
book1 = Book("The Great Gatsby", "F. Scott Fitzgerald")

# Print one attribute to confirm the object is built correctly
print(f"Book Title: {book1.title}")
print(f"Book Author: {book1.author}")
print(f"Is Available: {book1.is_available}")
# Out:
# Book Title: The Great Gatsby
# Book Author: F. Scott Fitzgerald
# Is Available: True
