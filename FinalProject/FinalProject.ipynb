# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler-Fronczke-CIS-115/blob/main/FinalProject/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# N/a

# FUNCTION DEFINITIONS
def add_expense(expenses_list, category, vendor, amount, date):
    record = {
        'category': category,
        'vendor': vendor,
# needed to change the amount to float because code breaks when a blank space is entered
        'amount': float(amount),
        'date': date
    }
    expenses_list.append(record)


# LOGIC FOR TESTING
expenses = []


print("--- Data Entry Test ---")
cat = input("Enter Category: ")
ven = input("Enter Vendor: ")
amt = input("Enter Amount: ")
dat = input("Enter Date: ")


# error handling for the test logic
try:
    add_expense(expenses, cat, ven, amt, dat)
    print("\nCurrent List State:")
    print(expenses)
except ValueError:
    print("\nError: The amount entered was not a valid number. Please try again.")
# Out:
# --- Data Entry Test ---
# Enter Category: e
# Enter Vendor: e
# Enter Amount: 112
# Enter Date: e
#
# Current List State:
# [{'category': 'e', 'vendor': 'e', 'amount': 112.0, 'date': 'e'}]
