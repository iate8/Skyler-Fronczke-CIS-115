# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler-Fronczke-CIS-115/blob/main/FinalProject/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# N/a

# FUNCTION DEFINITIONS
# def add_expense(expenses_list, category, vendor, amount, date):
    # Create a dictionary for the expense
    # Append dictionary to the expenses_list

# def calculate_totals(expenses_list, filter_type, filter_value=None):
    # Loop through list
    # If filter matches, add amount to running total
    # Return final sum

# PROGRAM LOGIC
# empty list 'expenses'
# Start while loop for menu
# If choice is 1: Collect inputs and call add_expense
# If choice is 2: Prompt for sub-menu (All, Category, Vendor) and call calculation
# If choice is 3: Break loop and exit
