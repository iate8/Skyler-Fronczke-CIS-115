# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler-Fronczke-CIS-115/blob/main/week11/week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS

#make function add_students
#while loop to keep asking for student names
#user types done then stop the loop
#prompt for a grade between 0 and 100
#check if the grade is invalid or not
#if else statement for if its valid or if its not valid

#make function calculate_average
#takes the gradebook dictionary as a parameter
#get all grades using .values()
#add all grades together
#divide by number of students
#return the average
#if dictionary is empty do something

# PROGRAM LOGIC

#create an empty dictionary called gradebook
#call add_students to fill the dictionary
#call calculate_average to get class average
#print each student's name and grade
#print the class average formatted to 2 decimal places
