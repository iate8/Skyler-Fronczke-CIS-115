# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler-Fronczke-CIS-115/blob/main/week11/week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# Define a function named calculate_rectangle that accepts length and width
# Inside the function, calculate the area by multiplying length by width
# Calculate the perimeter using the formula 2 * (length + width)
# Pack both the calculated area and perimeter into a single tuple
# Return the tuple containing (area, perimeter)

# PROGRAM LOGIC
# Test the calculate_rectangle function
# Ask the user to input the length of the rectangle
# Convert the input string to a float
# Print the result
