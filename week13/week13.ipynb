# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler-Fronczke-CIS-115/blob/main/week13/week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# N/A

# FUNCTION DEFINITIONS
# Define a function 'write_entry' that accepts 'filename' and 'entry_text'
#   Open 'filename' in append mode ('a')
#   Write 'entry_text' to the file
#   Ensure a newline character is added after the entry for readability
#   Close the file

# Define a function 'read_journal' that accepts 'filename'
#   Attempt to open 'filename' in read mode ('r')
#   If FileNotFoundError occurs (journal doesn't exist yet):
#     Print a message indicating the journal is empty or doesn't exist
#   Else (file opens successfully):
#     Read the entire content of the file
#     Print the content to the screen, preceded by a header
#     Close the file

# PROGRAM LOGIC
# Set the default journal filename
# Start an infinite loop (while True)
#   Prompt the user to choose an action: (W)rite, (R)ead, or (Q)uit
#   Convert the user's input to lowercase and remove leading/trailing whitespace
#   If the choice is 'q' (quit):
#     Break out of the loop
#   Else if the choice is 'w' (write):
#     Prompt the user for their journal entry
#     Call the 'write_entry' function with the filename and the user's entry
#     Print a confirmation message ('Entry saved.')
#   Else if the choice is 'r' (read):
#     Call the 'read_journal' function with the filename
#   Else (invalid choice):
#     Print an error message for invalid input
