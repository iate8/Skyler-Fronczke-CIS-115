# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler-Fronczke-CIS-115/blob/main/week6/week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# 1. Import math
import math

# FUNCTION DEFINITIONS

# 1. Define area(radius): returns pi * r squared
def circle_area(radius):
  area = math.pi * (radius ** 2)
  return area

# 2. Define circumference(radius): returns 2 * pi * r
def circle_circumference(radius):
  circumference = 2 * math.pi * radius
  return circumference

# 3. Define volume(radius, height):
#    - Call area(radius) and multiply by height.
#    - Return the result.
def cylinder_volume(radius, height):
  volume = math.pi * (radius ** 2) * height
  return volume



# PROGRAM LOGIC
# 1. Input for radius (float)
input_radius = float(input("Enter radius:"))

# 2. Call and print area and circumference.
area = circle_area(input_radius)
print("Area:", area)

circumference = circle_circumference(input_radius)
print("Circumference:", circumference)

# 3. Input for height (float)
input_height = float(input("Enter height:"))

# 4. Call and print volume.
volume = cylinder_volume(input_radius, input_height)
print("Volume:", volume)
# Out:
# Enter radius:800
# Area: 2010619.2982974676
# Circumference: 5026.548245743669
# Enter height:1
# Volume: 2010619.2982974676
