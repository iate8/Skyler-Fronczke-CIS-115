# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler-Fronczke-CIS-115/blob/main/REAL%20week%203/COMPLETION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assign values to name, goal, birth_year and current year
name = "Jordan"
goal = "Become software developer."
birth_year = 2004
current_year = 2026

#Calculate age
age = current_year - birth_year

#Print top border with string multiplication
print("=" * 25)

#Print bio sentences
print("Hi my name is" , name , "and I am" , age , "years old. I want to" , goal)

#Print bottom border with string multiplication
print("=" * 25)
# Out:
# ...
# Hi my name is Jordan and I am 22 years old. I want to Become software developer.
# ...
